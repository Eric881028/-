# %% [markdown]
# <a href="https://colab.research.google.com/github/Eric881028/-/blob/0418/%E5%B7%A8%E9%87%8F%E8%B3%87%E6%96%990418%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#使用gdown套件存取google drive
# !mkdir -p cat_dog_train
# !mkdir -p bird_train
# !pip install --upgrade --no-cache-dir gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# ...

# %%
#下載圖片至VM端
url='https://drive.google.com/uc?id=1NYAsskGbvXpuoj5i-pHlGXhoVyXgQV0J'
output='cat_dog_train/PetImages.zip'
import gdown
gdown.download(url=url,output=output,quiet=False,fuzzy=True)
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1NYAsskGbvXpuoj5i-pHlGXhoVyXgQV0J
# From (redirected): https://drive.google.com/uc?id=1NYAsskGbvXpuoj5i-pHlGXhoVyXgQV0J&confirm=t&uuid=8d798455-1c62-4f61-a376-79599be094cc
# To: /content/cat_dog_train/PetImages.zip
# 100%|██████████| 723M/723M [00:05<00:00, 127MB/s]
# 'cat_dog_train/PetImages.zip'

# %%
url='https://drive.google.com/file/d/1zPU-NqUoz6Ny5Hm5TohANP3oOI7w0UCt/view?usp=share_link'
output='bird_train/bird.zip'
import gdown
gdown.download(url=url,output=output,quiet=False,fuzzy=True)
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1zPU-NqUoz6Ny5Hm5TohANP3oOI7w0UCt
# From (redirected): https://drive.google.com/uc?id=1zPU-NqUoz6Ny5Hm5TohANP3oOI7w0UCt&confirm=t&uuid=6335c1fb-7f84-4688-be20-5fb299f19003
# To: /content/bird_train/bird.zip
# 100%|██████████| 1.86G/1.86G [00:15<00:00, 117MB/s]
# 'bird_train/bird.zip'

# %%
url='https://drive.google.com/file/d/1NgmjVrRug_qPqlfU_Zb2O-kyd5Hblaat/view'
output='bird_train/Bird.zip'
import gdown
gdown.download(url=url,output=output,quiet=False,fuzzy=True)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NgmjVrRug_qPqlfU_Zb2O-kyd5Hblaat
# To: /content/bird_train/Bird.zip
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 31.6MB/s]
# 'bird_train/Bird.zip'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#解壓縮圖片檔，會產生兩個目錄分別是 Cat 與 Dogn
# !unzip cat_dog_train/PetImages.zip -d cat_dog_train
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: cat_dog_train/PetImages/Dog/5165.jpg
#   inflating: cat_dog_train/PetImages/Dog/5166.jpg
#   inflating: cat_dog_train/PetImages/Dog/5167.jpg
#   inflating: cat_dog_train/PetImages/Dog/5168.jpg
#   inflating: cat_dog_train/PetImages/Dog/5169.jpg
#   inflating: cat_dog_train/PetImages/Dog/517.jpg
#   inflating: cat_dog_train/PetImages/Dog/5170.jpg
#   inflating: cat_dog_train/PetImages/Dog/5171.jpg
#   inflating: cat_dog_train/PetImages/Dog/5172.jpg
#   inflating: cat_dog_train/PetImages/Dog/5173.jpg
#   inflating: cat_dog_train/PetImages/Dog/5174.jpg
#   inflating: cat_dog_train/PetImages/Dog/5177.jpg
#   inflating: cat_dog_train/PetImages/Dog/5178.jpg
#   inflating: cat_dog_train/PetImages/Dog/5179.jpg
#   inflating: cat_dog_train/PetImages/Dog/518.jpg
#   inflating: cat_dog_train/PetImages/Dog/5180.jpg
#   inflating: cat_dog_train/PetImages/Dog/5181.jpg
#   inflating: cat_dog_train/PetImages/Dog/5182.jpg
# ...

# %%
#解壓縮圖片檔，會產生目錄 bird
# !unzip bird_train/bird.zip -d bird_train
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/071.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/072.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/073.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/074.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/075.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/076.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/077.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/078.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/079.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/080.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/081.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/082.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/083.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/084.jpg
#   inflating: bird_train/train/VICTORIA CROWNED PIGEON/085.jpg
# ...

# %%
#解壓縮圖片檔，會產生目錄 bird
# !unzip bird_train/Bird.zip -d bird_train
# Out:
# Archive:  bird_train/Bird.zip
#    creating: bird_train/Bird/
#   inflating: bird_train/Bird/001.jpg
#   inflating: bird_train/Bird/002.jpg
#   inflating: bird_train/Bird/003.jpg
#   inflating: bird_train/Bird/004.jpg
#   inflating: bird_train/Bird/005.jpg
#   inflating: bird_train/Bird/006.jpg
#   inflating: bird_train/Bird/007.jpg
#   inflating: bird_train/Bird/008.jpg
#   inflating: bird_train/Bird/009.jpg
#   inflating: bird_train/Bird/010.jpg
#   inflating: bird_train/Bird/011.jpg
#   inflating: bird_train/Bird/012.jpg
#   inflating: bird_train/Bird/013.jpg
#   inflating: bird_train/Bird/014.jpg
#   inflating: bird_train/Bird/015.jpg
#   inflating: bird_train/Bird/016.jpg
#   inflating: bird_train/Bird/017.jpg
#   inflating: bird_train/Bird/018.jpg
#   inflating: bird_train/Bird/019.jpg
#   inflating: bird_train/Bird/020.jpg
#   inflating: bird_train/Bird/021.jpg
#   inflating: bird_train/Bird/022.jpg
#   inflating: bird_train/Bird/023.jpg
#   inflating: bird_train/Bird/024.jpg
# ...

# %%
#在colab環境中，安裝conda
# !pip install -q condacolab

# %%
import condacolab

condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:23
# 🔁 Restarting kernel...

# %%
#檢查conda版本
# !conda --version
# Out:
# conda 22.11.1

# %%
#檢查conda安裝位置

# !which conda
# Out:
# /usr/local/bin/conda

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Keras
from tensorflow.keras.applications.imagenet_utils import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16
from keras.utils import plot_model

# %%
#檢查tensorflow版本
#tensorflow版本與keras版本同步

tf.__version__
# Out:
# '2.12.0'

# %%
model=VGG16(weights="imagenet")

# %%
model.summary()
plot_model(model,to_file="vgg16model.png")
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
import numpy as np

# %%
img = image.load_img('cat_dog_train/PetImages/Cat/10.jpg',target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
img_data = preprocess_input(x)
classes = model.predict(img_data)

print(classes)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [[1.31108891e-06 1.26614259e-05 6.25716041e-07 6.79014022e-07
#   2.15808413e-07 2.67879977e-06 2.85406628e-07 2.77364627e-04
#   4.08443710e-04 3.39730032e-05 4.74000899e-06 2.05877750e-05
#   6.29385322e-05 3.09016650e-05 1.85342628e-06 9.92765272e-05
#   1.76179121e-04 4.76331224e-05 3.92618749e-05 1.72366663e-06
#   1.03321909e-05 2.26683356e-03 8.28239077e-04 3.01171094e-04
#   5.80666168e-03 1.47889273e-06 1.15196713e-06 2.54515794e-06
#   1.47734488e-06 3.19952278e-07 1.52516861e-06 1.85821909e-06
#   2.86462091e-06 6.25259133e-07 1.97262622e-07 8.28353950e-06
#   4.81892494e-06 3.07950795e-05 4.82833684e-06 1.35143137e-05
#   1.22712081e-05 4.82081850e-06 2.75620869e-06 1.31260704e-05
#   1.01287398e-04 3.45352760e-06 3.12302254e-05 4.85562259e-06
#   4.02888389e-07 1.24348946e-06 6.46539320e-06 3.64944572e-05
#   3.12862812e-06 5.30833495e-06 1.11533991e-05 3.50483333e-06
# ...

# %%
classes.shape
# Out:
# (1, 1000)

# %%
# Process your result for human
# pred_class = preds.argmax(axis=-1)            # Simple argmax
pred_class = decode_predictions(classes, top=1)   # ImageNet Decode
result = str(pred_class[0][0][1])               # Convert to string

# %%
result
# Out:
# 'tabby'

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FAEE1C2D610>

# %%
img = image.load_img('cat_dog_train/PetImages/Dog/1000.jpg',target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
img_data = preprocess_input(x)
classes = model.predict(img_data)

print(classes)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# [[1.65641190e-08 1.10441214e-07 1.33960782e-07 1.29728637e-08
#   6.00163546e-08 3.52099292e-08 3.18638882e-07 1.30102960e-02
#   6.74118346e-04 1.07149826e-03 1.57154396e-08 9.19508647e-09
#   1.18387904e-08 6.80464964e-08 2.99449852e-08 3.52217057e-07
#   7.43917852e-08 1.72027569e-07 7.68089990e-07 1.02106057e-07
#   1.82555269e-08 3.32459138e-07 1.78402763e-06 2.31014928e-05
#   1.86613477e-07 7.11433188e-08 1.11958567e-08 5.44879413e-08
#   2.35661268e-08 1.14525037e-07 6.94391344e-09 4.96425701e-09
#   1.01224309e-08 3.45541594e-07 4.65813287e-07 4.18149035e-08
#   6.47557044e-07 1.28750827e-07 3.31259145e-08 1.53953692e-07
#   1.57828790e-08 2.04266275e-08 3.90505361e-09 3.46915350e-08
#   3.81665473e-08 2.49896516e-07 1.91578469e-08 1.99690442e-09
#   1.13870399e-07 1.10415760e-06 5.81874133e-07 3.35299319e-07
#   2.21046577e-08 2.22517400e-08 1.87057125e-07 2.91131617e-08
# ...

# %%
# Process your result for human
# pred_class = preds.argmax(axis=-1)            # Simple argmax
pred_class = decode_predictions(classes, top=1)   # ImageNet Decode
result = str(pred_class[0][0][1])               # Convert to string

# %%
result
# Out:
# 'briard'

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FAEE1AC95B0>

# %%
img = image.load_img('bird_train/Bird/001.jpg',target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
img_data = preprocess_input(x)
classes = model.predict(img_data)

print(classes)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# [[1.76944781e-07 5.07385245e-08 2.60815636e-06 1.73178887e-06
#   4.49349827e-05 3.99154305e-06 1.06929920e-05 2.93514859e-06
#   1.84510409e-05 5.59923876e-07 3.06451693e-06 4.08407641e-06
#   4.47352051e-07 2.15165437e-06 2.20101711e-07 5.49919378e-07
#   3.65003075e-06 1.37903015e-04 2.55448016e-04 8.54657355e-06
#   9.69989924e-06 1.93650939e-03 2.80283624e-04 3.04719753e-04
#   3.26353472e-07 1.29596501e-07 1.32735787e-08 1.16668666e-08
#   1.84837802e-07 9.15532439e-07 4.47847242e-07 1.49075206e-07
#   7.27765439e-08 1.01040757e-06 1.64479161e-06 8.26128485e-07
#   5.34066339e-06 7.50376117e-08 1.02769615e-08 4.43332446e-08
#   8.09868865e-08 2.12749729e-08 1.31707107e-08 4.78908557e-09
#   6.66902054e-08 1.22431061e-08 1.38389339e-07 6.55547572e-09
#   2.96788976e-08 1.75546759e-08 2.21408683e-07 8.34056237e-08
#   1.14558941e-06 2.43060441e-07 1.09437288e-07 5.27143520e-08
# ...

# %%
# Process your result for human
# pred_class = preds.argmax(axis=-1)            # Simple argmax
pred_class = decode_predictions(classes, top=1)   # ImageNet Decode
result = str(pred_class[0][0][1])               # Convert to string

# %%
result
# Out:
# 'albatross'

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FAEE04162E0>

# %%
#儲存模型目錄為my_model
#my_model目錄可以備份回google drive，以便後續使用

model.save('my_model')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: my_model/assets
# INFO:tensorflow:Assets written to: my_model/assets

# %%
#假設新開一個colab，可以將先前存在google drive的模型檔案 my_model拉過來
#讀取 my_model 模型檔案

new_model = tf.keras.models.load_model('my_model')

#檢視模型結構
#注意觀察模型參數數量: 2,782,649
new_model.summary()
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 180, 180, 3)  0           ['input_4[0][0]']
#
#  rescaling (Rescaling)          (None, 180, 180, 3)  0           ['sequential[0][0]']
#
#  conv2d (Conv2D)                (None, 90, 90, 32)   896         ['rescaling[0][0]']
#
#  batch_normalization (BatchNorm  (None, 90, 90, 32)  128         ['conv2d[0][0]']
#  alization)
#
# ...

# %%
#如果不想存整個目錄，也可以存模型檔案
model.save('my_model.h5')
#讀取模型檔案
new_model1 = tf.keras.models.load_model('my_model.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
#check its architecture
new_model1.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 180, 180, 3)  0           ['input_4[0][0]']
#
#  rescaling (Rescaling)          (None, 180, 180, 3)  0           ['sequential[0][0]']
#
#  conv2d (Conv2D)                (None, 90, 90, 32)   896         ['rescaling[0][0]']
#
#  batch_normalization (BatchNorm  (None, 90, 90, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 90, 90, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 90, 90, 64)   18496       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 90, 90, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
# ...

# %%
#再次inference貓咪圖片，看看結果有沒有差別
img = keras.preprocessing.image.load_img(
    "cat_dog_train/PetImages/Cat1/my_cat.jpg", target_size=image_size
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = new_model1.predict(img_array)
score = predictions[0]
print(
    "This image is %.2f percent cat and %.2f percent dog."
    % (100 * (1 - score), 100 * score)
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-59-273bbef06359> in <cell line: 2>()
#       1 #再次inference貓咪圖片，看看結果有沒有差別
# ----> 2 img = keras.preprocessing.image.load_img(
#       3     "cat_dog_train/PetImages/Cat1/my_cat.jpg", target_size=image_size
#       4 )
#       5 img_array = keras.preprocessing.image.img_to_array(img)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cat_dog_train/PetImages/Cat1/my_cat.jpg'
